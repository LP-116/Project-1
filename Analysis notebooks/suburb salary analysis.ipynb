# %% [markdown]
# ### Analysis detail:
#
# In this section we take the below csv files created in other analysis and combine them into one file which is then used to create a heatmap that shows the average income by postcode.
#
# The csv's used include:
# * Vic suburbs median house prices for the past 10 years (with postcodes added for each suburb)
# * The Vic income by postcode
# * The Vic suburbs latitude and Longitude
#
# There is a second part of the analysis that looks at the relationship between suburb house price and average income for the year of 2018.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import scipy.stats as st
import requests
import json
import gmaps
import os

# Importing Google maps API key
from api_keys import g_key

# Importing all the csv files we need to merge.
prices_path = "Data files/prices with postcode.csv"
salary_path = "Data files/vic_wages_postcode.csv"
lat_lng_path = "Data files/subs lat and lng.csv"

# Reading in the files.
prices_df = pd.read_csv(prices_path)
salary_df = pd.read_csv(salary_path)
lat_lng_df = pd.read_csv(lat_lng_path)

# %%
# Merging the first 2 csv files.
combined_data = pd.merge(prices_df, salary_df, on="Postcode", how="left")

# %%
# Displaying the dataframe.
combined_data
# Out:
#            Suburb       2010      2011      2012      2013       2014  \
# 0      ABBOTSFORD   736000.0  730000.0  714000.0  792500.0   862500.0
# 1      ABERFELDIE  1046500.0  994000.0  852500.0  947500.0  1045000.0
# 2    AIREYS INLET   606000.0  680000.0  634000.0  664000.0   625500.0
# 3    AIRPORT WEST   575000.0  557500.0  495000.0  532000.0   575000.0
# 4       ALBANVALE   320000.0  317000.0  310000.0  313000.0   326500.0
# ..            ...        ...       ...       ...       ...        ...
# 657        YARRAM   166000.0  195500.0  215000.0  190000.0   202500.0
# 658    YARRAVILLE   647000.0  607000.0  613000.0  696000.0   710000.0
# 659    YARRAWONGA   297000.0  270000.0  300000.0  302500.0   297000.0
# 660           YEA   240000.0  270000.0  255000.0  260000.0   255000.0
# 661        YINNAR   280500.0  208000.0  221500.0  220000.0   240000.0
#
#           2015       2016       2017       2018       2019       2020  \
# 0     925000.0  1187500.0  1280000.0  1192500.0  1030000.0  1150000.0
# 1    1207500.0  1300000.0  1453000.0  1500000.0  1390000.0  1592500.0
# 2     680000.0   715000.0   737500.0   869000.0   985000.0  1005000.0
# 3     635000.0   742000.0   845000.0   847500.0   790000.0   900000.0
# 4     345000.0   439000.0   526500.0   546000.0   512000.0   563000.0
# ..         ...        ...        ...        ...        ...        ...
# 657   245000.0   230000.0   225000.0   218000.0   240000.0   260000.0
# 658   810000.0   900500.0  1000000.0  1045000.0   971000.0   950000.0
# 659   300500.0   320000.0   324500.0   345000.0   375000.0   398000.0
# 660   260000.0   305000.0   386500.0   392500.0   435500.0   416500.0
# 661   182500.0   230000.0   270000.0   245000.0   255000.0   237500.0
#
#     Postcode  Average income
# 0       3067    71646.487443
# 1       3040    78506.787179
# 2       3231    57331.725581
# 3       3042    61603.532710
# 4       3021    42223.782280
# ..       ...             ...
# 657     3971    42120.961846
# 658     3013    76176.411410
# 659     3730    46917.999593
# 660     3717    46668.789632
# 661     3869    57817.767072
#
# [662 rows x 14 columns]

# %%
# Merging the 3rd csv file.
combined_data = pd.merge(combined_data, lat_lng_df, on="Suburb", how="left")

# %%
# Displaying the dataframe.
combined_data
# Out:
#            Suburb       2010      2011      2012      2013       2014  \
# 0      ABBOTSFORD   736000.0  730000.0  714000.0  792500.0   862500.0
# 1      ABERFELDIE  1046500.0  994000.0  852500.0  947500.0  1045000.0
# 2    AIREYS INLET   606000.0  680000.0  634000.0  664000.0   625500.0
# 3    AIRPORT WEST   575000.0  557500.0  495000.0  532000.0   575000.0
# 4       ALBANVALE   320000.0  317000.0  310000.0  313000.0   326500.0
# ..            ...        ...       ...       ...       ...        ...
# 657        YARRAM   166000.0  195500.0  215000.0  190000.0   202500.0
# 658    YARRAVILLE   647000.0  607000.0  613000.0  696000.0   710000.0
# 659    YARRAWONGA   297000.0  270000.0  300000.0  302500.0   297000.0
# 660           YEA   240000.0  270000.0  255000.0  260000.0   255000.0
# 661        YINNAR   280500.0  208000.0  221500.0  220000.0   240000.0
#
#           2015       2016       2017       2018       2019       2020  \
# 0     925000.0  1187500.0  1280000.0  1192500.0  1030000.0  1150000.0
# 1    1207500.0  1300000.0  1453000.0  1500000.0  1390000.0  1592500.0
# 2     680000.0   715000.0   737500.0   869000.0   985000.0  1005000.0
# 3     635000.0   742000.0   845000.0   847500.0   790000.0   900000.0
# 4     345000.0   439000.0   526500.0   546000.0   512000.0   563000.0
# ..         ...        ...        ...        ...        ...        ...
# 657   245000.0   230000.0   225000.0   218000.0   240000.0   260000.0
# 658   810000.0   900500.0  1000000.0  1045000.0   971000.0   950000.0
# 659   300500.0   320000.0   324500.0   345000.0   375000.0   398000.0
# 660   260000.0   305000.0   386500.0   392500.0   435500.0   416500.0
# 661   182500.0   230000.0   270000.0   245000.0   255000.0   237500.0
#
#     Postcode  Average income        Lat         Lng
# 0       3067    71646.487443 -37.803000  145.002000
# 1       3040    78506.787179 -37.762000  144.901000
# 2       3231    57331.725581 -38.461511  144.105766
# 3       3042    61603.532710 -37.726234  144.881353
# 4       3021    42223.782280 -37.746000  144.765000
# ..       ...             ...        ...         ...
# 657     3971    42120.961846 -38.565594  146.675105
# 658     3013    76176.411410 -37.820274  144.882170
# 659     3730    46917.999593 -36.027113  145.999058
# 660     3717    46668.789632 -37.222937  145.407020
# 661     3869    57817.767072 -38.316667  146.316667
#
# [662 rows x 16 columns]

# %%
# Dropping any rows with missing data.
final_data = combined_data.dropna()
final_data
# Out:
#            Suburb       2010      2011      2012      2013       2014  \
# 0      ABBOTSFORD   736000.0  730000.0  714000.0  792500.0   862500.0
# 1      ABERFELDIE  1046500.0  994000.0  852500.0  947500.0  1045000.0
# 2    AIREYS INLET   606000.0  680000.0  634000.0  664000.0   625500.0
# 3    AIRPORT WEST   575000.0  557500.0  495000.0  532000.0   575000.0
# 4       ALBANVALE   320000.0  317000.0  310000.0  313000.0   326500.0
# ..            ...        ...       ...       ...       ...        ...
# 657        YARRAM   166000.0  195500.0  215000.0  190000.0   202500.0
# 658    YARRAVILLE   647000.0  607000.0  613000.0  696000.0   710000.0
# 659    YARRAWONGA   297000.0  270000.0  300000.0  302500.0   297000.0
# 660           YEA   240000.0  270000.0  255000.0  260000.0   255000.0
# 661        YINNAR   280500.0  208000.0  221500.0  220000.0   240000.0
#
#           2015       2016       2017       2018       2019       2020  \
# 0     925000.0  1187500.0  1280000.0  1192500.0  1030000.0  1150000.0
# 1    1207500.0  1300000.0  1453000.0  1500000.0  1390000.0  1592500.0
# 2     680000.0   715000.0   737500.0   869000.0   985000.0  1005000.0
# 3     635000.0   742000.0   845000.0   847500.0   790000.0   900000.0
# 4     345000.0   439000.0   526500.0   546000.0   512000.0   563000.0
# ..         ...        ...        ...        ...        ...        ...
# 657   245000.0   230000.0   225000.0   218000.0   240000.0   260000.0
# 658   810000.0   900500.0  1000000.0  1045000.0   971000.0   950000.0
# 659   300500.0   320000.0   324500.0   345000.0   375000.0   398000.0
# 660   260000.0   305000.0   386500.0   392500.0   435500.0   416500.0
# 661   182500.0   230000.0   270000.0   245000.0   255000.0   237500.0
#
#     Postcode  Average income        Lat         Lng
# 0       3067    71646.487443 -37.803000  145.002000
# 1       3040    78506.787179 -37.762000  144.901000
# 2       3231    57331.725581 -38.461511  144.105766
# 3       3042    61603.532710 -37.726234  144.881353
# 4       3021    42223.782280 -37.746000  144.765000
# ..       ...             ...        ...         ...
# 657     3971    42120.961846 -38.565594  146.675105
# 658     3013    76176.411410 -37.820274  144.882170
# 659     3730    46917.999593 -36.027113  145.999058
# 660     3717    46668.789632 -37.222937  145.407020
# 661     3869    57817.767072 -38.316667  146.316667
#
# [647 rows x 16 columns]

# %%
# Saving the merged df's to a new csv file.
final_data.to_csv("Data files/median_house_price_income.csv", encoding="utf-8", index=False, header=True)

# %%
# Using the income data to generate a heatmap.
gmaps.configure(api_key=g_key)

locations = final_data[["Lat", "Lng"]]

salary = final_data["Average income"]/10000

fig = gmaps.figure(zoom_level=8, center=(-38, 145))

heat_layer = gmaps.heatmap_layer(locations, weights=salary, dissipating=False, max_intensity=10, point_radius=0.05)
fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# **Analysis Part 2:** Suburb and Income correlation
# Unfortunately we were only able to find 1 year of data broken down by suburb.
# This data was for 2018 and therefore below analysis is based on the house pricing in the year 2018.

# %%
# Start by getting the relevant columns
income_sub = final_data.loc[:, ["Suburb", "2018", "Average income"]]
income_sub
# Out:
#            Suburb       2018  Average income
# 0      ABBOTSFORD  1192500.0    71646.487443
# 1      ABERFELDIE  1500000.0    78506.787179
# 2    AIREYS INLET   869000.0    57331.725581
# 3    AIRPORT WEST   847500.0    61603.532710
# 4       ALBANVALE   546000.0    42223.782280
# ..            ...        ...             ...
# 657        YARRAM   218000.0    42120.961846
# 658    YARRAVILLE  1045000.0    76176.411410
# 659    YARRAWONGA   345000.0    46917.999593
# 660           YEA   392500.0    46668.789632
# 661        YINNAR   245000.0    57817.767072
#
# [647 rows x 3 columns]

# %%
# Next, we ranked the price column and income column from highest to lowest.
income_sub["Price Rank"] = income_sub["2018"].rank(method="max", ascending=False)
income_sub["Income Rank"] = income_sub["Average income"].rank(method="max", ascending=False)
income_sub
# Out:
#            Suburb       2018  Average income  Price Rank  Income Rank
# 0      ABBOTSFORD  1192500.0    71646.487443        83.0         81.0
# 1      ABERFELDIE  1500000.0    78506.787179        41.0         53.0
# 2    AIREYS INLET   869000.0    57331.725581       167.0        213.0
# 3    AIRPORT WEST   847500.0    61603.532710       178.0        142.0
# 4       ALBANVALE   546000.0    42223.782280       355.0        613.0
# ..            ...        ...             ...         ...          ...
# 657        YARRAM   218000.0    42120.961846       600.0        616.0
# 658    YARRAVILLE  1045000.0    76176.411410       114.0         64.0
# 659    YARRAWONGA   345000.0    46917.999593       501.0        484.0
# 660           YEA   392500.0    46668.789632       466.0        493.0
# 661        YINNAR   245000.0    57817.767072       577.0        200.0
#
# [647 rows x 5 columns]

# %%
# Then we calculated the difference in the ranking
income_sub["Rank difference"] = income_sub["Price Rank"] - income_sub["Income Rank"]
income_sub
# Out:
#            Suburb       2018  Average income  Price Rank  Income Rank  \
# 0      ABBOTSFORD  1192500.0    71646.487443        83.0         81.0
# 1      ABERFELDIE  1500000.0    78506.787179        41.0         53.0
# 2    AIREYS INLET   869000.0    57331.725581       167.0        213.0
# 3    AIRPORT WEST   847500.0    61603.532710       178.0        142.0
# 4       ALBANVALE   546000.0    42223.782280       355.0        613.0
# ..            ...        ...             ...         ...          ...
# 657        YARRAM   218000.0    42120.961846       600.0        616.0
# 658    YARRAVILLE  1045000.0    76176.411410       114.0         64.0
# 659    YARRAWONGA   345000.0    46917.999593       501.0        484.0
# 660           YEA   392500.0    46668.789632       466.0        493.0
# 661        YINNAR   245000.0    57817.767072       577.0        200.0
#
#      Rank difference
# 0                2.0
# 1              -12.0
# 2              -46.0
# 3               36.0
# 4             -258.0
# ..               ...
# 657            -16.0
# 658             50.0
# 659             17.0
# 660            -27.0
# 661            377.0
#
# [647 rows x 6 columns]

# %%
# Creating a final rank to get an indication of suburbs with the biggest difference.
income_sub["Final Rank"] = ((income_sub["Price Rank"] + income_sub["Income Rank"]) / 2).round(0)

# %%
# Sorting by final rank
income_sub = income_sub.sort_values("Final Rank")
income_sub["2018"] = income_sub["2018"].map("${:,.2f}".format)
income_sub["Average income"] = income_sub["Average income"].map("${:,.2f}".format)

# %%
# Viewing the top 10 results.
income_sub.head(10)
# Out:
#              Suburb           2018 Average income  Price Rank  Income Rank  \
# 591          TOORAK  $4,700,000.00    $196,816.36         1.0          1.0
# 198  EAST MELBOURNE  $2,675,000.00    $185,437.16         3.0          2.0
# 84         BRIGHTON  $2,879,000.00    $137,485.19         2.0          5.0
# 378     MIDDLE PARK  $2,650,000.00    $142,702.30         5.0          4.0
# 357         MALVERN  $2,661,000.00    $128,720.09         4.0          6.0
# 108      CANTERBURY  $2,536,500.00    $127,984.91         6.0          7.0
# 259        HAWTHORN  $2,488,000.00    $106,270.52         7.0         11.0
# 17         ARMADALE  $2,341,500.00    $106,775.50         9.0         10.0
# 476         PORTSEA  $2,180,000.00    $115,369.55        12.0          9.0
# 5       ALBERT PARK  $2,070,000.00    $142,702.30        15.0          4.0
#
#      Rank difference  Final Rank
# 591              0.0         1.0
# 198              1.0         2.0
# 84              -3.0         4.0
# 378              1.0         4.0
# 357             -2.0         5.0
# 108             -1.0         6.0
# 259             -4.0         9.0
# 17              -1.0        10.0
# 476              3.0        10.0
# 5               11.0        10.0

# %%
# Viewing the bottom 10 results.
income_sub.tail(10)
# Out:
#            Suburb         2018 Average income  Price Rank  Income Rank  \
# 327     LAKE BOGA  $220,000.00     $40,249.99       598.0        633.0
# 125      CHARLTON  $150,000.00     $42,103.63       624.0        617.0
# 550     ST ARNAUD  $145,000.00     $41,970.42       627.0        620.0
# 554      STANHOPE  $161,500.00     $41,085.94       622.0        626.0
# 650    WYCHEPROOF  $124,500.00     $41,581.98       633.0        622.0
# 622    WEDDERBURN  $130,000.00     $40,240.20       631.0        634.0
# 184        DONALD  $145,000.00     $39,539.08       627.0        640.0
# 180   DERRINALLUM  $122,500.00     $40,087.21       634.0        636.0
# 444     NYAH WEST  $135,000.00     $39,043.77       628.0        645.0
# 480  PYRAMID HILL  $100,000.00     $40,276.00       642.0        632.0
#
#      Rank difference  Final Rank
# 327            -35.0       616.0
# 125              7.0       620.0
# 550              7.0       624.0
# 554             -4.0       624.0
# 650             11.0       628.0
# 622             -3.0       632.0
# 184            -13.0       634.0
# 180             -2.0       635.0
# 444            -17.0       636.0
# 480             10.0       637.0
