# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import scipy.stats as st
import requests
import json
import gmaps
import os
import warnings

# Importing Google maps API key
from api_keys import g_key

vic_wages_path = "Data files/wage by postcode.csv"
vic_wages_df = pd.read_csv(vic_wages_path, encoding='cp1252')

# %%
vic_wages_df
# Out:
#      Taxation statistics 2017–18 Individuals: Selected items, by state/territory1 and postcode, 2017–18 income year2  \
# 0                                                 Notes
# 1                                     State/ Territory1
# 2                                                   ACT
# 3                                                   ACT
# 4                                                   ACT
# ...                                                 ...
# 2694                                                 WA
# 2695                                                NaN
# 2696                                                NaN
# 2697                                                NaN
# 2698                                                NaN
#
#      Unnamed: 1                  Unnamed: 2                    Unnamed: 3  \
# 0           NaN                         NaN                           NaN
# 1      Postcode  Number of individuals\nno.  Taxable income or loss3\nno.
# 2          2600                       5,962                         5,930
# 3          2601                       2,810                         2,763
# 4          2602                      20,613                        20,483
# ...         ...                         ...                           ...
# 2694   WA other                       3,256                         3,209
# 2695        NaN                         NaN                           NaN
# 2696        NaN                         NaN                           NaN
# 2697        NaN                         NaN                           NaN
# 2698        NaN                         NaN                           NaN
#
#                       Unnamed: 4                  Unnamed: 5  \
# 0                            NaN                         NaN
# 1     Taxable income or loss3\n$  Tax on taxable income\nno.
# 2                    641,711,873                       5,216
# 3                    182,477,415                       1,965
# 4                  1,501,063,447                      17,529
# ...                          ...                         ...
# 2694                 224,663,265                       2,625
# 2695                         NaN                         NaN
# 2696                         NaN                         NaN
# 2697                         NaN                         NaN
# 2698                         NaN                         NaN
#
#                     Unnamed: 6          Unnamed: 7        Unnamed: 8  \
# 0                          NaN                 NaN               NaN
# 1     Tax on taxable income\n$  Medicare levy\nno.  Medicare levy\n$
# 2                  188,657,453               4,578        11,922,622
# 3                   45,726,322               1,617         3,116,999
# 4                  360,186,331              15,218        27,101,890
# ...                        ...                 ...               ...
# 2694                56,621,432               2,228         4,172,678
# 2695                       NaN                 NaN               NaN
# 2696                       NaN                 NaN               NaN
# 2697                       NaN                 NaN               NaN
# 2698                       NaN                 NaN               NaN
#
#                         Unnamed: 9  ...                         Unnamed: 138  \
# 0                              NaN  ...                                  NaN
# 1     Medicare levy surcharge\nno.  ...  Small business income tax offset\n$
# 2                              172  ...                              195,787
# 3                               84  ...                               47,189
# 4                              706  ...                              385,946
# ...                            ...  ...                                  ...
# 2694                            66  ...                              287,854
# 2695                           NaN  ...                                  NaN
# 2696                           NaN  ...                                  NaN
# 2697                           NaN  ...                                  NaN
# 2698                           NaN  ...                                  NaN
#
#                     Unnamed: 139              Unnamed: 140  \
# 0                            NaN                       NaN
# 1     Low income tax offset\nno.  Low income tax offset\n$
# 2                          1,844                   542,095
# 3                            842                   264,294
# 4                          7,833                 2,370,538
# ...                          ...                       ...
# 2694                       1,310                   396,937
# 2695                         NaN                       NaN
# 2696                         NaN                       NaN
# 2697                         NaN                       NaN
# 2698                         NaN                       NaN
#
#                                    Unnamed: 141  \
# 0                                           NaN
# 1     People with private health insurance\nno.
# 2                                         4,791
# 3                                         1,578
# 4                                        13,909
# ...                                         ...
# 2694                                      2,267
# 2695                                        NaN
# 2696                                        NaN
# 2697                                        NaN
# 2698                                        NaN
#
#                                            Unnamed: 142  \
# 0                                                   NaN
# 1     Private health insurance - your Australian Gov...
# 2                                                 3,707
# 3                                                 1,072
# 4                                                11,012
# ...                                                 ...
# 2694                                              1,987
# 2695                                                NaN
# 2696                                                NaN
# 2697                                                NaN
# 2698                                                NaN
#
#                                            Unnamed: 143  \
# 0                                                   NaN
# 1     Private health insurance - your Australian Gov...
# 2                                             2,790,528
# 3                                               616,878
# 4                                             6,406,248
# ...                                                 ...
# 2694                                          1,354,769
# 2695                                                NaN
# 2696                                                NaN
# 2697                                                NaN
# 2698                                                NaN
#
#                               Unnamed: 144  \
# 0                                      NaN
# 1     Private health insurance rebate\nno.
# 2                                      412
# 3                                      177
# 4                                    1,476
# ...                                    ...
# 2694                                   201
# 2695                                   NaN
# 2696                                   NaN
# 2697                                   NaN
# 2698                                   NaN
#
#                             Unnamed: 145  \
# 0                                    NaN
# 1     Private health insurance rebate\n$
# 2                                188,764
# 3                                 58,759
# 4                                448,229
# ...                                  ...
# 2694                              60,919
# 2695                                 NaN
# 2696                                 NaN
# 2697                                 NaN
# 2698                                 NaN
#
#                                            Unnamed: 146  \
# 0                                                   NaN
# 1     Excess private health reduction or refund (reb...
# 2                                                 1,793
# 3                                                   407
# 4                                                 4,237
# ...                                                 ...
# 2694                                                673
# 2695                                                NaN
# 2696                                                NaN
# 2697                                                NaN
# 2698                                                NaN
#
#                                            Unnamed: 147
# 0                                                   NaN
# 1     Excess private health reduction or refund (reb...
# 2                                               963,746
# 3                                               158,793
# 4                                             1,582,238
# ...                                                 ...
# 2694                                            278,242
# 2695                                                NaN
# 2696                                                NaN
# 2697                                                NaN
# 2698                                                NaN
#
# [2699 rows x 148 columns]

# %%
vic_wages_df.columns = vic_wages_df.iloc[1]

# %%
vic_wages_df
# Out:
# 1     State/ Territory1  Postcode  Number of individuals\nno.  \
# 0                 Notes       NaN                         NaN
# 1     State/ Territory1  Postcode  Number of individuals\nno.
# 2                   ACT      2600                       5,962
# 3                   ACT      2601                       2,810
# 4                   ACT      2602                      20,613
# ...                 ...       ...                         ...
# 2694                 WA  WA other                       3,256
# 2695                NaN       NaN                         NaN
# 2696                NaN       NaN                         NaN
# 2697                NaN       NaN                         NaN
# 2698                NaN       NaN                         NaN
#
# 1     Taxable income or loss3\nno.  Taxable income or loss3\n$  \
# 0                              NaN                         NaN
# 1     Taxable income or loss3\nno.  Taxable income or loss3\n$
# 2                            5,930                 641,711,873
# 3                            2,763                 182,477,415
# 4                           20,483               1,501,063,447
# ...                            ...                         ...
# 2694                         3,209                 224,663,265
# 2695                           NaN                         NaN
# 2696                           NaN                         NaN
# 2697                           NaN                         NaN
# 2698                           NaN                         NaN
#
# 1     Tax on taxable income\nno.  Tax on taxable income\n$  \
# 0                            NaN                       NaN
# 1     Tax on taxable income\nno.  Tax on taxable income\n$
# 2                          5,216               188,657,453
# 3                          1,965                45,726,322
# 4                         17,529               360,186,331
# ...                          ...                       ...
# 2694                       2,625                56,621,432
# 2695                         NaN                       NaN
# 2696                         NaN                       NaN
# 2697                         NaN                       NaN
# 2698                         NaN                       NaN
#
# 1     Medicare levy\nno.  Medicare levy\n$  Medicare levy surcharge\nno.  ...  \
# 0                    NaN               NaN                           NaN  ...
# 1     Medicare levy\nno.  Medicare levy\n$  Medicare levy surcharge\nno.  ...
# 2                  4,578        11,922,622                           172  ...
# 3                  1,617         3,116,999                            84  ...
# 4                 15,218        27,101,890                           706  ...
# ...                  ...               ...                           ...  ...
# 2694               2,228         4,172,678                            66  ...
# 2695                 NaN               NaN                           NaN  ...
# 2696                 NaN               NaN                           NaN  ...
# 2697                 NaN               NaN                           NaN  ...
# 2698                 NaN               NaN                           NaN  ...
#
# 1     Small business income tax offset\n$  Low income tax offset\nno.  \
# 0                                     NaN                         NaN
# 1     Small business income tax offset\n$  Low income tax offset\nno.
# 2                                 195,787                       1,844
# 3                                  47,189                         842
# 4                                 385,946                       7,833
# ...                                   ...                         ...
# 2694                              287,854                       1,310
# 2695                                  NaN                         NaN
# 2696                                  NaN                         NaN
# 2697                                  NaN                         NaN
# 2698                                  NaN                         NaN
#
# 1     Low income tax offset\n$  People with private health insurance\nno.  \
# 0                          NaN                                        NaN
# 1     Low income tax offset\n$  People with private health insurance\nno.
# 2                      542,095                                      4,791
# 3                      264,294                                      1,578
# 4                    2,370,538                                     13,909
# ...                        ...                                        ...
# 2694                   396,937                                      2,267
# 2695                       NaN                                        NaN
# 2696                       NaN                                        NaN
# 2697                       NaN                                        NaN
# 2698                       NaN                                        NaN
#
# 1    Private health insurance - your Australian Government rebate received\nno.  \
# 0                                                   NaN
# 1     Private health insurance - your Australian Gov...
# 2                                                 3,707
# 3                                                 1,072
# 4                                                11,012
# ...                                                 ...
# 2694                                              1,987
# 2695                                                NaN
# 2696                                                NaN
# 2697                                                NaN
# 2698                                                NaN
#
# 1    Private health insurance - your Australian Government rebate received\n$  \
# 0                                                   NaN
# 1     Private health insurance - your Australian Gov...
# 2                                             2,790,528
# 3                                               616,878
# 4                                             6,406,248
# ...                                                 ...
# 2694                                          1,354,769
# 2695                                                NaN
# 2696                                                NaN
# 2697                                                NaN
# 2698                                                NaN
#
# 1     Private health insurance rebate\nno.  \
# 0                                      NaN
# 1     Private health insurance rebate\nno.
# 2                                      412
# 3                                      177
# 4                                    1,476
# ...                                    ...
# 2694                                   201
# 2695                                   NaN
# 2696                                   NaN
# 2697                                   NaN
# 2698                                   NaN
#
# 1     Private health insurance rebate\n$  \
# 0                                    NaN
# 1     Private health insurance rebate\n$
# 2                                188,764
# 3                                 58,759
# 4                                448,229
# ...                                  ...
# 2694                              60,919
# 2695                                 NaN
# 2696                                 NaN
# 2697                                 NaN
# 2698                                 NaN
#
# 1    Excess private health reduction or refund (rebate reduced)\nno.  \
# 0                                                   NaN
# 1     Excess private health reduction or refund (reb...
# 2                                                 1,793
# 3                                                   407
# 4                                                 4,237
# ...                                                 ...
# 2694                                                673
# 2695                                                NaN
# 2696                                                NaN
# 2697                                                NaN
# 2698                                                NaN
#
# 1    Excess private health reduction or refund (rebate reduced)\n$
# 0                                                   NaN
# 1     Excess private health reduction or refund (reb...
# 2                                               963,746
# 3                                               158,793
# 4                                             1,582,238
# ...                                                 ...
# 2694                                            278,242
# 2695                                                NaN
# 2696                                                NaN
# 2697                                                NaN
# 2698                                                NaN
#
# [2699 rows x 148 columns]

# %%
vic_wage_clean = vic_wages_df.drop(vic_wages_df.columns.difference(["State/ Territory1", "Postcode", "Number of individuals\nno.",
                                                                   "Taxable income or loss3\n$"]), axis=1)
vic_wage_clean
# Out:
# 1     State/ Territory1  Postcode  Number of individuals\nno.  \
# 0                 Notes       NaN                         NaN
# 1     State/ Territory1  Postcode  Number of individuals\nno.
# 2                   ACT      2600                       5,962
# 3                   ACT      2601                       2,810
# 4                   ACT      2602                      20,613
# ...                 ...       ...                         ...
# 2694                 WA  WA other                       3,256
# 2695                NaN       NaN                         NaN
# 2696                NaN       NaN                         NaN
# 2697                NaN       NaN                         NaN
# 2698                NaN       NaN                         NaN
#
# 1     Taxable income or loss3\n$
# 0                            NaN
# 1     Taxable income or loss3\n$
# 2                    641,711,873
# 3                    182,477,415
# 4                  1,501,063,447
# ...                          ...
# 2694                 224,663,265
# 2695                         NaN
# 2696                         NaN
# 2697                         NaN
# 2698                         NaN
#
# [2699 rows x 4 columns]

# %%
vic_wage_clean.dropna()
# Out:
# 1     State/ Territory1  Postcode  Number of individuals\nno.  \
# 1     State/ Territory1  Postcode  Number of individuals\nno.
# 2                   ACT      2600                       5,962
# 3                   ACT      2601                       2,810
# 4                   ACT      2602                      20,613
# 5                   ACT      2603                       6,850
# ...                 ...       ...                         ...
# 2690                 WA      6979                          73
# 2691                 WA      6981                          80
# 2692                 WA      6984                          56
# 2693                 WA      6985                          73
# 2694                 WA  WA other                       3,256
#
# 1     Taxable income or loss3\n$
# 1     Taxable income or loss3\n$
# 2                    641,711,873
# 3                    182,477,415
# 4                  1,501,063,447
# 5                    792,701,438
# ...                          ...
# 2690                  12,998,541
# 2691                   6,407,000
# 2692                   4,695,050
# 2693                   5,256,510
# 2694                 224,663,265
#
# [2694 rows x 4 columns]

# %%
vic_filtered = vic_wage_clean.loc[vic_wage_clean["State/ Territory1"] == "VIC"]
vic_filtered
# Out:
# 1    State/ Territory1   Postcode Number of individuals\nno.  \
# 1609               VIC       3000                     24,559
# 1610               VIC       3001                        240
# 1611               VIC       3002                      3,709
# 1612               VIC       3003                      4,520
# 1613               VIC       3004                      8,178
# ...                ...        ...                        ...
# 2310               VIC       3992                        514
# 2311               VIC       3995                      5,406
# 2312               VIC       3996                      3,286
# 2313               VIC       8007                         51
# 2314               VIC  VIC other                      2,354
#
# 1    Taxable income or loss3\n$
# 1609              1,464,326,212
# 1610                 47,123,000
# 1611                687,786,435
# 1612                277,885,391
# 1613                976,363,798
# ...                         ...
# 2310                 23,766,246
# 2311                228,644,019
# 2312                164,139,183
# 2313                  4,771,423
# 2314                144,063,447
#
# [706 rows x 4 columns]

# %%
vic_filtered = vic_filtered.rename(columns={"State/ Territory1": "State", "Number of individuals\nno.": "No. of people", "Taxable income or loss3\n$": "Income"})
vic_filtered
# Out:
# 1    State   Postcode No. of people         Income
# 1609   VIC       3000        24,559  1,464,326,212
# 1610   VIC       3001           240     47,123,000
# 1611   VIC       3002         3,709    687,786,435
# 1612   VIC       3003         4,520    277,885,391
# 1613   VIC       3004         8,178    976,363,798
# ...    ...        ...           ...            ...
# 2310   VIC       3992           514     23,766,246
# 2311   VIC       3995         5,406    228,644,019
# 2312   VIC       3996         3,286    164,139,183
# 2313   VIC       8007            51      4,771,423
# 2314   VIC  VIC other         2,354    144,063,447
#
# [706 rows x 4 columns]
