# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import scipy.stats as st

# Importing Google maps API key
# from api_keys import g_key

mel_subs_path = "Data files/Victoria property sales report.csv"
mel_subs_df = pd.read_csv(mel_subs_path)

# %%
mel_subs_df
# Out:
#     Median House Prices 3rd Quarter 2020    Unnamed: 1    Unnamed: 2  \
# 0                                 SUBURB  Jul - Sep 19  Oct - Dec 19
# 1                                 TOORAK       4750000       5000000
# 2                               BRIGHTON       3005000       2707500
# 3                               DEEPDENE       2680000       2880000
# 4                           IVANHOE EAST       1853800       2044000
# ..                                   ...           ...           ...
# 780                                  NaN           NaN           NaN
# 781                                  NaN           NaN           NaN
# 782                                  NaN           NaN           NaN
# 783                                  NaN           NaN           NaN
# 784                                  NaN           NaN           NaN
#
#        Unnamed: 3   Unnamed: 4    Unnamed: 5    Unnamed: 6    Unnamed: 7  \
# ...

# %%
# Start by making the columns = the 2nd row in the dataset i.e. row index 0.
# This results in two rows of "headings"
mel_subs_df.columns = mel_subs_df.iloc[0]
mel_subs_df
# Out:
# 0          SUBURB  Jul - Sep 19  Oct - Dec 19  Jan - Mar 20  Apr- Jun 20  \
# 0          SUBURB  Jul - Sep 19  Oct - Dec 19  Jan - Mar 20  Apr- Jun 20
# 1          TOORAK       4750000       5000000       4500000      5550000
# 2        BRIGHTON       3005000       2707500       2964400      2825000
# 3        DEEPDENE       2680000       2880000       5475000      2915000
# 4    IVANHOE EAST       1853800       2044000       2145000      1712500
# ..            ...           ...           ...           ...          ...
# 780           NaN           NaN           NaN           NaN          NaN
# 781           NaN           NaN           NaN           NaN          NaN
# 782           NaN           NaN           NaN           NaN          NaN
# 783           NaN           NaN           NaN           NaN          NaN
# 784           NaN           NaN           NaN           NaN          NaN
#
# 0    Jul - Sep 20  No of sales   No of Sales   Jul - Sep 19  Apr - Jun 20  \
# ...

# %%
# Next want to drop the 2nd row because we don't want it anymore.
mel_subs_df = mel_subs_df.drop(mel_subs_df.index[0])

# %%
mel_subs_df = mel_subs_df.loc[:, mel_subs_df.columns.notnull()]
mel_subs_df
# Out:
# 0           SUBURB Jul - Sep 19 Oct - Dec 19 Jan - Mar 20 Apr- Jun 20  \
# 1           TOORAK      4750000      5000000      4500000     5550000
# 2         BRIGHTON      3005000      2707500      2964400     2825000
# 3         DEEPDENE      2680000      2880000      5475000     2915000
# 4     IVANHOE EAST      1853800      2044000      2145000     1712500
# 5    HAWTHORN EAST      2412500      2250000      2177500     2370000
# ..             ...          ...          ...          ...         ...
# 780            NaN          NaN          NaN          NaN         NaN
# 781            NaN          NaN          NaN          NaN         NaN
# 782            NaN          NaN          NaN          NaN         NaN
# 783            NaN          NaN          NaN          NaN         NaN
# 784            NaN          NaN          NaN          NaN         NaN
#
# 0   Jul - Sep 20 No of sales  No of Sales  Jul - Sep 19 Apr - Jun 20
# ...

# %%
mel_subs_df = mel_subs_df.dropna(axis=0, how='all')
mel_subs_df
# Out:
# 0           SUBURB Jul - Sep 19 Oct - Dec 19 Jan - Mar 20 Apr- Jun 20  \
# 1           TOORAK      4750000      5000000      4500000     5550000
# 2         BRIGHTON      3005000      2707500      2964400     2825000
# 3         DEEPDENE      2680000      2880000      5475000     2915000
# 4     IVANHOE EAST      1853800      2044000      2145000     1712500
# 5    HAWTHORN EAST      2412500      2250000      2177500     2370000
# ..             ...          ...          ...          ...         ...
# 758         KANIVA       119800       177000       137500       96000
# 759        RAINBOW        85000        67000        77500       60000
# 760         MINYIP        64500       140000        95000       65300
# 761       RUPANYUP       159000        85000       140000      140000
# 762            NaN          NaN          NaN          NaN         NaN
#
# 0   Jul - Sep 20  No of sales  No of Sales   Jul - Sep 19  Apr - Jun 20
# ...

# %%
mel_subs_df = mel_subs_df.dropna(subset=["SUBURB"])
mel_subs_df
# Out:
# 0           SUBURB Jul - Sep 19 Oct - Dec 19 Jan - Mar 20 Apr- Jun 20  \
# 1           TOORAK      4750000      5000000      4500000     5550000
# 2         BRIGHTON      3005000      2707500      2964400     2825000
# 3         DEEPDENE      2680000      2880000      5475000     2915000
# 4     IVANHOE EAST      1853800      2044000      2145000     1712500
# 5    HAWTHORN EAST      2412500      2250000      2177500     2370000
# ..             ...          ...          ...          ...         ...
# 757          OUYEN       112300        75000       143800       70500
# 758         KANIVA       119800       177000       137500       96000
# 759        RAINBOW        85000        67000        77500       60000
# 760         MINYIP        64500       140000        95000       65300
# 761       RUPANYUP       159000        85000       140000      140000
#
# 0   Jul - Sep 20 No of sales  No of Sales  Jul - Sep 19 Apr - Jun 20
# ...

# %%
mel_subs_df = mel_subs_df.iloc[:, 0:6]
mel_subs_df
# Out:
# 0           SUBURB Jul - Sep 19 Oct - Dec 19 Jan - Mar 20 Apr- Jun 20  \
# 1           TOORAK      4750000      5000000      4500000     5550000
# 2         BRIGHTON      3005000      2707500      2964400     2825000
# 3         DEEPDENE      2680000      2880000      5475000     2915000
# 4     IVANHOE EAST      1853800      2044000      2145000     1712500
# 5    HAWTHORN EAST      2412500      2250000      2177500     2370000
# ..             ...          ...          ...          ...         ...
# 757          OUYEN       112300        75000       143800       70500
# 758         KANIVA       119800       177000       137500       96000
# 759        RAINBOW        85000        67000        77500       60000
# 760         MINYIP        64500       140000        95000       65300
# 761       RUPANYUP       159000        85000       140000      140000
#
# 0   Jul - Sep 20
# 1        5750000
# 2        3325000
# 3        3150000
# 4        3125000
# 5        2806000
# ...

# %%
mel_subs_df = mel_subs_df.rename(columns={"Apr- Jun 20": "Apr - Jun 20"})
mel_subs_df
# Out:
# 0           SUBURB Jul - Sep 19 Oct - Dec 19 Jan - Mar 20 Apr - Jun 20  \
# 1           TOORAK      4750000      5000000      4500000      5550000
# 2         BRIGHTON      3005000      2707500      2964400      2825000
# 3         DEEPDENE      2680000      2880000      5475000      2915000
# 4     IVANHOE EAST      1853800      2044000      2145000      1712500
# 5    HAWTHORN EAST      2412500      2250000      2177500      2370000
# ..             ...          ...          ...          ...          ...
# 757          OUYEN       112300        75000       143800        70500
# 758         KANIVA       119800       177000       137500        96000
# 759        RAINBOW        85000        67000        77500        60000
# 760         MINYIP        64500       140000        95000        65300
# 761       RUPANYUP       159000        85000       140000       140000
#
# 0   Jul - Sep 20
# 1        5750000
# 2        3325000
# 3        3150000
# 4        3125000
# 5        2806000
# ...

# %%
mel_subs_df.count()
# Out:
# 0
# SUBURB          761
# Jul - Sep 19    761
# Oct - Dec 19    761
# Jan - Mar 20    761
# Apr - Jun 20    761
# Jul - Sep 20    761
# dtype: int64

# %%
avg_test = mel_subs_df.iloc[:,2].astype(float).mean()
avg_test
# Out:
# 740774.9014454664

# %%
suburb_count = mel_subs_df["SUBURB"].nunique()
jul_sep_avg = mel_subs_df.iloc[:,1].astype(float).mean()
# oct_dec_avg = mel_subs_df.iloc[:,2].astype(float).mean()
# jan_mar_avg = mel_subs_df.iloc[:,3].astype(float).mean()
# apr_jun_avg = mel_subs_df.iloc[:,4].astype(float).mean()
# jul_sep_avg = mel_subs_df.iloc[:,5].astype(float).mean()

# sub_stats_df = pd.DataFrame({"Suburb count": suburb_count, "Jul - Sep Average": jul_sep_avg,
#                              "Oct - Dec Average": oct_dec_avg, "Jan - Mar Average": jan_mar_avg,
#                             "Apr - Jun Average": apr_jun_avg, "Jul - Sep Average": jul_sep_avg})
# sub_stats_df

jul_sep_avg

# %%
# suburb_count = mel_subs_df["SUBURB"].nunique()
# jul_sep_avg = mel_subs_df["Jul - Sep 19"].mean()
# oct_dec_avg = mel_subs_df["Oct - Dec 19"].mean()
# jan_mar_avg = mel_subs_df["Jan - Mar 20"].mean()
# apr_jun_avg = mel_subs_df["Apr - Jun 20"].mean()
# jul_sep_avg = mel_subs_df["Jul - Sep 20"].mean()

# sub_stats_df = pd.DataFrame({"Suburb count": suburb_count, "Jul - Sep Average": jul_sep_avg,
#                              "Oct - Dec Average": oct_dec_avg, "Jan - Mar Average": jan_mar_avg,
#                             "Apr - Jun Average": apr_jun_avg, "Jul - Sep Average": jul_sep_avg})
# sub_stats_df
